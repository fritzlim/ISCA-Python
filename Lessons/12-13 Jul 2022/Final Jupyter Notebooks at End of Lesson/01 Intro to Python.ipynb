# %% [markdown]
# # Intro to Python
#
# In this notebook, we'll do some very basic Python to get you warmed up with programming. Experienced coders can try the exercises the end of each section, or if you already know intro Python, move ahead to the next notebook.

# %% [markdown]
# ## Variables
#
# Variables are used to store data. In Python, we use `=` to *assign* data from the right item, to the variable name in the left item. For example:

# %%
name = "Potato"
age = 36 # integer
weight = 108.5 # float (double)
print(name, age, weight)
# Out:
# Potato 36 108.5

# %% [markdown]
# Start your variables with letters--you can't use numbers, so `3banana` is not a valid variable name. For variables with many words, use underscores: `three_banana` or camel case: `threeBanana`.

# %% [markdown]
# ## Printing
#
# Use `print` to send information from your code to the results bar, underneath the cell.
#
# Try these lines of code, each on a separate cell:
#
# ```
# print("My name is Banana")
# ```
# ```
# print("My name is", name)
# ```
# ```
# print("My name is", name, "and my age is", age, "and my weight is", weight)
# ```

# %%
print("My name is Banana") # This is a comment. We use hashtag to indicate it.
# Out:
# My name is Banana

# %%
print("My name is", name)
# Out:
# My name is Potato

# %%
print("My name is", name, "and my age is", age, "and my weight is", weight)
# Out:
# My name is Potato and my age is 36 and my weight is 108.5

# %% [markdown]
# ## Operators
#
# You can do math in Python! It's like a really expensive (and clunky) calculator.

# %%
a = 10
b = 5
c = a + b
print(c)
# Out:
# 15

# %% [markdown]
# If the value of a changes, is the value of c affected?

# %%
a = 20
c = a + b
print(c) # when a changes, c isn't affected.
# Out:
# 15

# %% [markdown]
# ### Some other operations

# %% [markdown]
# #### Division

# %%
# you can do division within a print, too
print(a/b)
# Out:
# 4.0

# %% [markdown]
# #### String joining (concatenation)

# %%
# String joining (concatenation).

firstname = "James"
lastname = "Bond"
# firstname + lastname # The + operator has 2 roles: add numbers or join strings.

# # What if we use the + operator on a mixture of numbers and strings?
x = 3
# firstname + lastname + 3 # Gives an error because it's a mix of strings and numbers.
firstname + " " + lastname + " " + str(3) # Cast a number to a string.
# Out:
# 'James Bond 3'

# %% [markdown]
# #### String multiplication

# %%
# What if we multiply a string?

name = "Bob"
name * 5
# Out:
# 'BobBobBobBobBob'

# %% [markdown]
# #### What do the following do:

# %%
a = 3
a += 1 # Shortcut code for this: a = a + 1
a -= 1 # Shortcut for this: a = a - 1
a *= 2 # a = a * 2
a /= 2 # a = a / 2

a # We can omit the print(a) statement.
# Out:
# 3.0

# %% [markdown]
# ## Types
#
# Variables have **types**, of which you've seen three: **int**s (integers, whole numbers), **float**s (decimal numbers), and **str**s (strings of text, with inverted commas around them--single or double inverted commas are fine, as long as you're consistent).

# %%
type(52)
# Out:
# int

# %%
type(52.1)
# Out:
# float

# %%
type('52')
# Out:
# str

# %%
type("potato")
# Out:
# str

# %% [markdown]
# ### <font color="red">Exercise 1A: More operators</font>
#
# Why stop at four when we have more? Try to `print` these out, and write comments (with `#` in front) to say what they do.

# %%
a = 5 ** 2 # 5 to the power of 2, i.e. 5 * 5
b = 3 ** 3
c = 4 ** 5
d = 15 // 12 # floor division. See https://realpython.com/python-operators-expressions/
e = 12 // 15
f = 200 // 50
g = 200 // 51
h = 6 % 2 # modulo operator. It shows the remainder after division.
i_need_better_variable_names = 5 % 2
j = 9 % 5
k = 6 % 6
l = 0 % 7

# We often use modulo to detect whether a number is even or odd.
m = 2 % 2 # Result of 0 means an even number.
n = 3 % 2 # Result of 1 means an odd number.

# %%
# print(a,b,c,h,j,k,l)
print(d)
print(m, n)
# Out:
# 1
# 0 1

# %% [markdown]
# ### <font color="red">Exercise 1B: Calculate and print</font>
#
# What if I want to calculate the age of someone who's 3x my age?
#
# Edit the variables below, and print: "3 times my age is 108".

# %%
age=46  #CHANGE ME
n=3  #CHANGE ME
result = age * n

print(n,"times my age is",result) #this line needs fixing! FIXME!
# Out:
# 3 times my age is 138

# %% [markdown]
# ### <font color="red">Exercise 1C: Seconds in a year</font>
#
# Let's use Python as a glorified calculator again. Below is some code to help you get started--can you figure out how many seconds there are in a year?

# %%
num_seconds_in_minute = 60
num_minutes_in_hour = 60 # FIXME
num_hours_in_day = 24 # FIXME
num_days_in_year = 365 # FIXME
total = num_seconds_in_minute * num_minutes_in_hour * num_hours_in_day * num_days_in_year # FIXME
print("The number of seconds in a year is",total)

# We can format the string with an f-string.
print(f"The number of seconds in a year is {total:,}")
# Out:
# The number of seconds in a year is 31536000
# The number of seconds in a year is 31,536,000

# %% [markdown]
# #### String formatting with f-strings

# %%
#Example: using f-strings to add thousand seperators and round to two decimal places
name = "Fritz"
amt_due = 123456.7890

print(f"Hello {name}, you owe money")
print(f"Hello {name}, you owe {amt_due}")
print(f"Hello {name}, you owe {amt_due:,}")
print(f"Hello {name}, you owe {amt_due:.2f}")
print(f"Hello {name}, you owe {amt_due:,.2f}")
# Out:
# Hello Fritz, you owe money
# Hello Fritz, you owe 123456.789
# Hello Fritz, you owe 123,456.789
# Hello Fritz, you owe 123456.79
# Hello Fritz, you owe 123,456.79

# %% [markdown]
# ### <font color="red">Exercise 1D: Pixels</font>
#
# You are given the width and height of a screen in pixels. Calculate the total number of pixels on the screen and store them in a variable called `numberOfPixels`.

# %%
height = 1920
width = 1080

# Your code here
# number_of_pixels =
# number-of-pixels =

# Note that the spelling of numberOfPixels must be exact.
numberOfPixels = width * height # This naming convention is called camelCase.

# Some code to print out the results
print("For a screen with height", height, "pixels")
print("And width", width, "pixels")
print("The total number of pixels is", numberOfPixels)

# %% [markdown]
# ### <font color="red">Exercise 1E: Boys and girls</font>
#
# Calculate the percentage of boys (`percentBoys`) and the percentage of girls (`percentGirls`) in a class, and print it out.

# %%
numberOfBoys = 60
numberOfGirls = 20

# Your code here
total = numberOfBoys + numberOfGirls
percentBoys = 60/total * 100
percentGirls = 20/total * 100

print(f"The percentage of boys in the class is {percentBoys:.0f}%, and the percentage of girls is {percentGirls}%.")
# Out:
# The percentage of boys in the class is 75%, and the percentage of girls is 25.0%.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Functions

# %% [markdown]
# A function is a piece of reusable code that lets you run it again and again, but possibly with different parameters. Try running this function below with some different parameters:

# %%
def dogYearCalculator(age, multiplier):
    print("Your age is", age)
    print("Your age in dog years is", multiplier * age)

def dogYearCalculatorV2(): # A function without any parameters/arguments.
    print("Your age in dog years is", 46 * 7)

# %%
# To use a function, we need to call it.
dogYearCalculator(46, 7)
dogYearCalculatorV2()
# Out:
# Your age is 46
# Your age in dog years is 322
# Your age in dog years is 322

# %% [markdown]
# ##### There are some useful built-in functions, too! You've been using `print`, a function that prints things out. Let's now use it to print the results of other functions:

# %%
max(4, 6, 2)
# Out:
# 6

# %%
min(1, 2, -10)
# Out:
# -10

# %%
round(3.596)
# Out:
# 4

# %%
len("banana123#$%") # len is short for "length"
# Out:
# 12

# %% [markdown]
# Some functions are in _modules_, e.g. the `math` module. To get started, you have to first `import math`, then try the functions within. Here is some gratuitious trigonometry:

# %%
import math

# %%
print("Pi is", math.pi)
print("Pi is", round(math.pi, 2)) # Round a number to 2 decimal places.
# Out:
# Pi is 3.141592653589793
# Pi is 3.14

# %%
print("Cosine Pi is", math.cos(math.pi))
# Out:
# Cosine Pi is -1.0

# %%
help(math)

# %%
import math as m # if you're tired of typing "math", you can import it as a shorter name. So many letters saved!
print(m.pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ### <font color="red">Exercise 2A: Errors</font>
#
# If you make a typo, Python will give you an error. Some may look cryptic, but you can try to figure out what they're telling you based on the line of the error. Try running the below, and identifying the errors in the code.

# %%
name = "Banana"

# %%
age = 55
weeksPerYear = 52
weeks_lived = age * weeksPerYear

# %%
print(weeks_lived = age * weeksPerYear)
# Out:
# 2860

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ### <font color="red">Exercise 2B: Cube</font>
#
# Write a function, `cube(n)`, that takes in a number, `n`, and prints out the cubed result.

# %%
def cube(n):
    result = n ** 3 # FIXME
    print("The result is",result)

# %%
cube(6) # this line is to test your code
# Out:
# The result is 216

# %% [markdown]
# ### <font color="red">Exercise 2C: Using functions</font>
#
# Before running the code below, try predicting what each `print` statement will tell you. Can you explain what's going on with the `max` function call, between `rich` and `poor`?

# %%
rich = "gold"
poor = "tin"
max(rich, poor)
# Out:
# 'tin'

# %%
# Python considers strings greater than one another based off the character they begin with. It uses the following order:
# 0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# The farther to the right, the greater the character
# This ordering is based on the hexadecimal Unicode code point for each character,
# e.g. capital A is 0041, capital B is 0042, lowercase a is 0061, lowercase b is 0062, etc.
# Full table can be found here: https://www.ibm.com/docs/en/i/7.2?topic=tables-unicode-lowercase-uppercase-conversion-mapping-table

# For example:
max("a","A", "1")
# Out:
# 'a'

# %% [markdown]
# <hr>

# %% [markdown]
# ## Lists
#
# So far, we've stored information in single variables. This would be unwieldy if we're dealing with a lot of data, e.g. weather readings over a year--imagine declaring variables `rainfall1`, `rainfall2`, `rainfall3`, etc.
#
# We're going to introduce **lists** here--a way to store multiple pieces of data in one variable. The first list here is a list of pressure values, defined within square brackets `[]`, separated by commas:

# %%
pressures = [0.24, 0.25, 0.28, 0.23]

# %%
max(pressures)
# Out:
# 0.28

# %%
pressures
len(pressures) # this tells us the length (number of items in the list).
# Out:
# 4

# %% [markdown]
# ##### You can also access individual elements in a list, by using the **square bracket notation**.
#
# Add a square bracket after your variable name, then have a number in it with the **index** of the element you want to access. Computer scientists count from 0, so if you want the first item, it's at index 0; second item is at index 1.

# %%
print("The first item is", pressures[0])
# Out:
# The first item is 0.24

# %%
print("The third item is", pressures[3])
# Out:
# The third item is 0.23

# %%
# You can also change values using index notation. Once you do, the info within the list changes.
pressures[3] = 0.99
print(pressures)
# Out:
# [0.24, 0.25, 0.28, 0.99]

# %% [markdown]
# ##### These are some list functions you can use.
#
# How do you find out about them? [Search](https://encrypted.google.com/search?q=python+list+functions)!

# %%
pressures.append(0.45)
pressures.append(0.31)
pressures
# Out:
# [0.24, 0.25, 0.28, 0.23, 0.45, 0.31]

# %%
# print(pressures)
# pressures.insert(1, 0.01)
print(pressures)
pressures.insert(3, 0.5)
print(pressures)
# Out:
# [0.24, 0.01, 0.25, 0.28, 0.23, 0.45, 0.31]
# [0.24, 0.01, 0.25, 0.5, 0.28, 0.23, 0.45, 0.31]

# %%
pressures.append("Banana")
pressures
# Out:
# [0.24, 0.01, 0.25, 0.5, 0.28, 0.23, 0.45, 0.31, 'Banana']

# %%
# Can you figure out what this negative index does?
pressures[-3] # When counting backwards in a list, we start numbering from 1 not 0.
# Out:
# 0.45

# %% [markdown]
# ##### Here's something you can do with lists: **slice** them using the slice operator, a colon.
#
# Instead of providing a single number in the index, get back part of the list by providing a range of numbers, for example:

# %%
pressures[1:4] # item 1, 2, and 3 -- 4 not inclusive
# Out:
# [0.01, 0.25, 0.5]

# %% [markdown]
# ### <font color="red">Exercise 3A: I got a list, here's the order of my list that it's in</font>
#
# Here's a list. Can you do the following manipulations to it?
#
# * Append “apple” and 76 to the list.
# * Insert the value “cat” at index 3.
# * Insert the value 99 at the start of the list.
# * Find the index of “hello”.
# * Count the number of 76s in the list.
# * Remove the first occurrence of 76 from the list.
#
# Print out your final list to check your answer.

# %%
myList = [76, 92.3, 'hello', True, 4, 76]
# Space for your working here

# %% [markdown]
# #### Exercise 3A Answer

# %%
myList = [76, 92.3, 'hello', True, 4, 76] # True is a Boolean value.

myList.append("apple")
myList.append(76)
print(myList)

myList.insert(3, "cat")
print(myList)

print("The index of 'hello' is", myList.index("hello"))
print("The number of 76s in the list is", myList.count(76))

myList.remove(76)
print(myList)
# Out:
# [76, 92.3, 'hello', True, 4, 76, 'apple', 76]
# [76, 92.3, 'hello', 'cat', True, 4, 76, 'apple', 76]
# The index of 'hello' is 2
# The number of 76s in the list is 3
# [92.3, 'hello', 'cat', True, 4, 76, 'apple', 76]

# %% [markdown]
# ### <font color="red">Exercise 3B: Fill in the blanks</font>
#
# Fill in the blanks so that the program below produces the output shown:

# %% [raw]
# ```
# first time: [1, 3, 5]
# second time: [3, 5]
# ```

# %%
values = []
values.____(1)  #hint: we need to add values to the list somehow!
values.____(3)
values.____(5)
print('first time:', values)
values = values[____]  #hint: use list slicing!
print('second time:', values)

# %% [markdown]
# #### Exercise 3B Answer

# %%
values = [] # We need to tell Python what the variable called values is first before the code can use it.
values.append(1)
values.append(3)
values.append(5)
print('first time:', values)
values = values[1:]
print('second time:', values)
# Out:
# first time: [1, 3, 5]
# second time: [3, 5]

# %% [markdown]
# <hr>

# %% [markdown]
# ## Loops
#
# Now that we have lists, we want to be able to work on the data within them at one swoop, i.e. not have to edit `item[0]`, `item[1]`, `item[2]` one by one. For this, we can use a loop.
#
# A loop starts with `for`, ends with a colon, and subsequent lines are indented:

# %%
stuff = ["potatoes", "bananas", "pie"]

for thing in stuff:
    print(thing)
# Out:
# potatoes
# bananas
# pie

# %%
# We can call the looping variable any name really. E.g.:
for any_name_really in stuff:
    print(any_name_really)
# Out:
# potatoes
# bananas
# pie

# %% [markdown]
# ##### Indent all the statements in a loop.

# %%
# Many statements in a loop? Sure. Just make sure they're indented--have a tab before them.
for i in stuff:
    print("I like", i)
    print("I really really like",i)
    print("Mmmmmmm")
# Out:
# I like potatoes
# I really really like potatoes
# Mmmmmmm
# I like bananas
# I really really like bananas
# Mmmmmmm
# I like pie
# I really really like pie
# Mmmmmmm

# %% [markdown]
# ##### The `range()` function

# %%
# range will give you a sequence of numbers, starting from 0, up to but not including your range-number
for n in range(6):
    print(n)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for n in range(5):
    print(n)
    print(n*n)
    print(n*n*n)
    print("")

print("I'm done!")
# Out:
# 0
# 0
# 0
#
# 1
# 1
# 1
#
# 2
# 4
# 8
#
# 3
# 9
# 27
#
# 4
# 16
# 64
#
# I'm done!

# %%
for i in range(10):
    print("banana",i)
# Out:
# banana 0
# banana 1
# banana 2
# banana 3
# banana 4
# banana 5
# banana 6
# banana 7
# banana 8
# banana 9

# %% [markdown]
# ### <font color="red">Exercise 4A: Multiply everything</font>
#
# Given a list of values, print out 2x of everything. E.g. [1, 2, 3] will print out
#
# ```
# 2
# 4
# 6
# ```

# %% [markdown]
# #### Exercise 4A Answer

# %%
values = [1,2,3,4]

for i in values:
    print(i*2) #FIXME

# %% [markdown]
# ### <font color="red">Exercise 4B: Square everything</font>
#
# Given a list of values, print out the square of everything. E.g. [1, 2, 3] will print out
#
# ```
# 1
# 4
# 9
# ```

# %% [markdown]
# #### Exercise 4B Answer

# %%
values = [1,2,3,4]
for i in values:
    print(i**2) #FIXME
# Out:
# 1
# 4
# 9
# 16

# %% [markdown]
# ### <font color="red">Exercise 4C: Print this Christmas tree using a loop</font>
#
# ```
# *
# **
# ***
# ****
# ```

# %%
# some starter code
for i in range(4):
    print("*" * (i+1))
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# ### <font color="red">Exercise 4D: Print this symmetrical Christmas tree using a loop</font>
#
# ```
#    *
#   ***
#  *****
# *******
# ```

# %% [markdown]
# #### Exercise 4D Answer

# %% [markdown]
# ##### Working for the expressing the number of spaces in front of each star and the number of stars in terms of i and h:
#
# ![ISCA Python - Working for Symmetrical Christmaas Tree.jpg](data:image/jpeg;base64,...)

# %%
#Symmetrical Christmas Tree:
h=10
for i in range(h):
    print(" "*(h-(i+1))  +  "*"*(2*i+1))
# Out:
#          *
#         ***
#        *****
#       *******
#      *********
#     ***********
#    *************
#   ***************
#  *****************
# *******************

# %% [markdown]
# <hr>

# %% [markdown]
# ## Conditionals
#
# To have Python make decisions for us, we use `if` statements. These control whether blocks of code are run or not. Structurally, they're similar to `for` loops; you start with an `if`, end with a colon, and indent the block of code you want to run conditionally:

# %%
mass = 51

if mass > 50: # Will be either True or False.
    print("That's a large mass")
    print("And this is also shown.")
if mass <= 45:
    print("That's a small mass")
if mass == 47:                        ## notice the ==, not =
    print("That's EXACTLY RIGHT")
# # Doesn't work because this else is linked only to the if statement above it.
# # Let's fix this after we learn about elif down below.
# else:
#     print("That's just some mass")
    
print("The mass is", mass) 

# Edit the value of mass, and try this block out again.
# We can also use <= amd >=
# Out:
# That's a large mass
# And this is also shown.
# The mass is 51

# %%
temperature = 35
precipitation = 99

# you can define multiple conditions with and, or

if temperature > 30 and precipitation > 90:
    print("It's a hot and muggy day")
# Out:
# It's a hot and muggy day

# %% [markdown]
# That seemed rather pointless, because we _knew_ what the values were before we ran the loop. Conditionals become more useful when dealing with data we don't define ourselves, e.g. when the data comes in a list:

# %%
costs = [3.24, 1.07, 3.22, 5.86, 1.91]
for c in costs:
    if c > 3.0:
        print(c, 'is large!')
# Out:
# 3.24 is large!
# 3.22 is large!
# 5.86 is large!

# %% [markdown]
# `else` can be used following an `if`, to specify an alternative course of action:

# %%
costs = [3.24, 1.07, 3.22, 5.86, 1.91]
for c in costs:
    if c > 3.0:
        print(c, 'is large!')
    else:
        print(c, 'is alright, I guess.')
# Out:
# 3.24 is large!
# 1.07 is alright, I guess.
# 3.22 is large!
# 5.86 is large!
# 1.91 is alright, I guess.

# %% [markdown]
# and `elif` can be used to define more conditions:

# %%
costs = [3.24, 1.07, 3.22, 5.86, 1.91]
for c in costs:
    if c > 5.0:
        print(c, 'is HUGE!')
    if c > 3.0:
        print(c, 'is large!')
    else:
        print(c, 'is alright, I guess.')
        
# notice we had to re-order the conditions? Can you figure out why?

# %% [markdown]
# ### <font color="red">Exercise 5A: Print this list, but numbered</font>
#
# Given a list of values, print them out, but with numbering. E.g.:
#
# ```
# Day 1 reading: 0.44
# Day 2 reading: 0.01
# Day 3 reading: 0.24
# ```

# %% [markdown]
# #### Exercise 5A Answer
#
# Note: this first exercise doesn't use conditionals, but the following ones will!

# %%
readings = [0.44, 0.01, 0.24]
index = 1 # hint!

for r in readings: 
    # print("Day " + str(index) + " reading: " + str(r)) # FIXME
    print(f"Day {str(index)} reading: {str(r)}") # FIXME
    index += 1
# Out:
# Day 1 reading: 0.44
# Day 2 reading: 0.01
# Day 3 reading: 0.24

# %% [markdown]
# ### <font color="red">Exercise 5B: Panic if something is too low</font>
#
# Same as above, but insert a huge warning if the value is below 0.1.
#
# ```
# Day 1 reading: 0.44
# Day 2 reading: 0.01   WHAT! THIS IS TOO LOW!
# Day 3 reading: 0.24
# ```

# %% [markdown]
# #### Exercise 5B Answer

# %%
readings = [0.44, 0.01, 0.24, 0.02]
index = 1 # hint!

for r in readings: 
    if r <= 0.01:
      # print("Day " + str(index) + " reading: " + str(r) + "    WHAT! THIS IS TOO LOW!")
      print(f"Day {str(index)} reading: {str(r)}   WHAT! THIS IS TOO LOW!")
    else:
      # print("Day " + str(index) + " reading: " + str(r))
      print(f"Day {str(index)} reading: {str(r)}")
    index += 1
# Out:
# Day 1 reading: 0.44
# Day 2 reading: 0.01   WHAT! THIS IS TOO LOW!
# Day 3 reading: 0.24
# Day 4 reading: 0.02

# %% [markdown]
# <hr>

# %% [markdown]
# ## Further reading
#
# Want to learn more? We recommend the following:
#
# * [How to think like a Computer Scientist](https://openbookproject.net/thinkcs/python/english3e/), an interactive online book
# * [Automate the Boring Stuff with Python](https://automatetheboringstuff.com/), for your lifehacks. Also available on Udemy as video.
